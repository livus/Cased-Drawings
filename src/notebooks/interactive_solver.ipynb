# %%
from importlib import reload
import sys
sys.path.insert(0, '../')   # adjust path so Python finds the src/ folder

import file_backed_interface
import draw_cd
reload(draw_cd)
reload(file_backed_interface)

from IPython.display import display

ui = file_backed_interface.create_file_backed_interface()
display(ui)
